# %%
import numpy as np
import _pickle as pickle

# %%
with open('fingerprint.dat', 'rb') as fp:
    X_train = pickle.load(fp)
    X_train_std = pickle.load(fp)
    X_test = pickle.load(fp)
    X_test_std = pickle.load(fp)
    y_train = pickle.load(fp)
    y_test = pickle.load(fp)

# %%
print("X_train_std.shape: ", X_train_std.shape)
print("y_train.shape: ", y_train.shape)
# Out:
# X_train_std.shape:  (400, 6)
# y_train.shape:  (400,)

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
ada_clf = AdaBoostClassifier(DecisionTreeClassifier(random_state = 42), 
                             algorithm="SAMME.R", 
                             random_state = 42)

# %%
learning_pts = []
learning_threshold = 0
for x in range(0,10):
    learning_threshold += 0.1
    learning_pts.append(learning_threshold)
print(learning_pts)
# Out:
# [0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.6, 0.7, 0.7999999999999999, 0.8999999999999999, 0.9999999999999999]

# %%
param_grid = [
#     {'n_estimators': [i for i in range(20,40,2)], {'base_estimator__max_depth': 2, 'learning_rate': 0.6, 'n_estimators': 22}
    {'n_estimators': [i for i in range(20,25)], 
    'learning_rate': learning_pts,
    "base_estimator__max_depth" : [i for i in range(1,10)]} 
#       {'n_estimators': [i for i in range(1,10)], 'learning_rate': learning_pts}
]

# %%
grid_ada_clf = GridSearchCV(ada_clf, param_grid, cv=5, verbose=10)

# %%
grid_ada_clf.fit(X_train_std, y_train)
# Out:
# Fitting 5 folds for each of 450 candidates, totalling 2250 fits
# [CV] base_estimator__max_depth=1, learning_rate=0.1, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.1, n_estimators=20, score=0.9625, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.1, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.1, n_estimators=20, score=0.975, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.1, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.1, n_estimators=20, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.1, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.1, n_estimators=20, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.1, n_estimators=20 .
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# [CV]  base_estimator__max_depth=1, learning_rate=0.1, n_estimators=20, score=0.95, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.1, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.1, n_estimators=21, score=0.9625, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.1, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.1, n_estimators=21, score=0.975, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.1, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.1, n_estimators=21, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.1, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.1, n_estimators=21, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.1, n_estimators=21 .
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.5s remaining:    0.0s
# [CV]  base_estimator__max_depth=1, learning_rate=0.1, n_estimators=21, score=0.95, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.1, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.1, n_estimators=22, score=0.9625, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.1, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.1, n_estimators=22, score=0.975, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.1, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.1, n_estimators=22, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.1, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.1, n_estimators=22, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.1, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.1, n_estimators=22, score=0.95, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.1, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.1, n_estimators=23, score=0.9625, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.1, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.1, n_estimators=23, score=0.975, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.1, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.1, n_estimators=23, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.1, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.1, n_estimators=23, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.1, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.1, n_estimators=23, score=0.95, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.1, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.1, n_estimators=24, score=0.9625, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.1, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.1, n_estimators=24, score=0.975, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.1, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.1, n_estimators=24, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.1, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.1, n_estimators=24, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.1, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.1, n_estimators=24, score=0.95, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.2, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.2, n_estimators=20, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.2, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.2, n_estimators=20, score=0.975, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.2, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.2, n_estimators=20, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.2, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.2, n_estimators=20, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.2, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.2, n_estimators=20, score=0.95, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.2, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.2, n_estimators=21, score=0.9375, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.2, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.2, n_estimators=21, score=0.975, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.2, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.2, n_estimators=21, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.2, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.2, n_estimators=21, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.2, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.2, n_estimators=21, score=0.95, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.2, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.2, n_estimators=22, score=0.9375, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.2, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.2, n_estimators=22, score=0.975, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.2, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.2, n_estimators=22, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.2, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.2, n_estimators=22, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.2, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.2, n_estimators=22, score=0.95, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.2, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.2, n_estimators=23, score=0.9125, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.2, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.2, n_estimators=23, score=0.975, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.2, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.2, n_estimators=23, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.2, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.2, n_estimators=23, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.2, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.2, n_estimators=23, score=0.95, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.2, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.2, n_estimators=24, score=0.9125, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.2, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.2, n_estimators=24, score=0.975, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.2, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.2, n_estimators=24, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.2, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.2, n_estimators=24, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.2, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.2, n_estimators=24, score=0.95, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=20
# [CV]  base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=20, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=20
# [CV]  base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=20, score=0.975, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=20
# [CV]  base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=20, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=20
# [CV]  base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=20, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=20
# [CV]  base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=20, score=0.95, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=21
# [CV]  base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=21, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=21
# [CV]  base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=21, score=0.975, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=21
# [CV]  base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=21, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=21
# [CV]  base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=21, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=21
# [CV]  base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=21, score=0.95, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=22
# [CV]  base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=22, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=22
# [CV]  base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=22, score=0.975, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=22
# [CV]  base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=22, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=22
# [CV]  base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=22, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=22
# [CV]  base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=22, score=0.95, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=23
# [CV]  base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=23, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=23
# [CV]  base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=23, score=0.975, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=23
# [CV]  base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=23, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=23
# [CV]  base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=23, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=23
# [CV]  base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=23, score=0.95, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=24
# [CV]  base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=24, score=0.925, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=24
# [CV]  base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=24, score=0.975, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=24
# [CV]  base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=24, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=24
# [CV]  base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=24, score=0.925, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=24
# [CV]  base_estimator__max_depth=1, learning_rate=0.30000000000000004, n_estimators=24, score=0.95, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.4, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.4, n_estimators=20, score=0.925, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.4, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.4, n_estimators=20, score=0.9625, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.4, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.4, n_estimators=20, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.4, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.4, n_estimators=20, score=0.925, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.4, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.4, n_estimators=20, score=0.95, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.4, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.4, n_estimators=21, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.4, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.4, n_estimators=21, score=0.9625, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.4, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.4, n_estimators=21, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.4, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.4, n_estimators=21, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.4, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.4, n_estimators=21, score=0.95, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.4, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.4, n_estimators=22, score=0.925, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.4, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.4, n_estimators=22, score=0.9625, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.4, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.4, n_estimators=22, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.4, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.4, n_estimators=22, score=0.925, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.4, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.4, n_estimators=22, score=0.95, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.4, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.4, n_estimators=23, score=0.9, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.4, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.4, n_estimators=23, score=0.9625, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.4, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.4, n_estimators=23, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.4, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.4, n_estimators=23, score=0.925, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.4, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.4, n_estimators=23, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.4, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.4, n_estimators=24, score=0.9, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.4, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.4, n_estimators=24, score=0.9625, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.4, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.4, n_estimators=24, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.4, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.4, n_estimators=24, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.4, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.4, n_estimators=24, score=0.9375, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.5, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.5, n_estimators=20, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.5, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.5, n_estimators=20, score=0.9625, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.5, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.5, n_estimators=20, score=1.0, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.5, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.5, n_estimators=20, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.5, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.5, n_estimators=20, score=0.95, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.5, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.5, n_estimators=21, score=0.9, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.5, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.5, n_estimators=21, score=0.9625, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.5, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.5, n_estimators=21, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.5, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.5, n_estimators=21, score=0.9375, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.5, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.5, n_estimators=21, score=0.95, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.5, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.5, n_estimators=22, score=0.9, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.5, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.5, n_estimators=22, score=0.9625, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.5, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.5, n_estimators=22, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.5, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.5, n_estimators=22, score=0.9375, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.5, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.5, n_estimators=22, score=0.95, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.5, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.5, n_estimators=23, score=0.9, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.5, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.5, n_estimators=23, score=0.9625, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.5, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.5, n_estimators=23, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.5, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.5, n_estimators=23, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.5, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.5, n_estimators=23, score=0.9375, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.5, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.5, n_estimators=24, score=0.9, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.5, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.5, n_estimators=24, score=0.9625, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.5, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.5, n_estimators=24, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.5, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.5, n_estimators=24, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.5, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.5, n_estimators=24, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.6, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.6, n_estimators=20, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.6, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.6, n_estimators=20, score=0.9625, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.6, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.6, n_estimators=20, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.6, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.6, n_estimators=20, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.6, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.6, n_estimators=20, score=0.9375, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.6, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.6, n_estimators=21, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.6, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.6, n_estimators=21, score=0.9625, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.6, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.6, n_estimators=21, score=1.0, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.6, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.6, n_estimators=21, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.6, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.6, n_estimators=21, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.6, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.6, n_estimators=22, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.6, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.6, n_estimators=22, score=0.9625, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.6, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.6, n_estimators=22, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.6, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.6, n_estimators=22, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.6, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.6, n_estimators=22, score=0.9375, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.6, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.6, n_estimators=23, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.6, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.6, n_estimators=23, score=0.9625, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.6, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.6, n_estimators=23, score=1.0, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.6, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.6, n_estimators=23, score=0.925, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.6, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.6, n_estimators=23, score=0.9375, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.6, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.6, n_estimators=24, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.6, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.6, n_estimators=24, score=0.9625, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.6, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.6, n_estimators=24, score=1.0, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.6, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.6, n_estimators=24, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.6, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.6, n_estimators=24, score=0.9375, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.7, n_estimators=20, score=0.9375, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.7, n_estimators=20, score=0.9625, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.7, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.7, n_estimators=20, score=1.0, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.7, n_estimators=20, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.7, n_estimators=20 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.7, n_estimators=20, score=0.925, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.7, n_estimators=21, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.7, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.7, n_estimators=21, score=0.9625, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.7, n_estimators=21, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.7, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.7, n_estimators=21, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.7, n_estimators=21 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.7, n_estimators=21, score=0.925, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.7, n_estimators=22, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.7, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.7, n_estimators=22, score=0.9625, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.7, n_estimators=22, score=1.0, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.7, n_estimators=22, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.7, n_estimators=22 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.7, n_estimators=22, score=0.925, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.7, n_estimators=23, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.7, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.7, n_estimators=23, score=0.9625, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.7, n_estimators=23, score=1.0, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.7, n_estimators=23, score=0.95, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.7, n_estimators=23 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.7, n_estimators=23, score=0.9375, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.7, n_estimators=24, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.7, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.7, n_estimators=24, score=0.9625, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.7, n_estimators=24, score=1.0, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.7, n_estimators=24, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.7, n_estimators=24 .
# [CV]  base_estimator__max_depth=1, learning_rate=0.7, n_estimators=24, score=0.9375, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=20
# [CV]  base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=20, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=20
# [CV]  base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=20, score=0.9625, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=20
# [CV]  base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=20, score=1.0, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=20
# [CV]  base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=20, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=20
# [CV]  base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=20, score=0.95, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=21
# [CV]  base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=21, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=21
# [CV]  base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=21, score=0.9625, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=21
# [CV]  base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=21, score=1.0, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=21
# [CV]  base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=21, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=21
# [CV]  base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=21, score=0.9375, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=22
# [CV]  base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=22, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=22
# [CV]  base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=22, score=0.9625, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=22
# [CV]  base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=22, score=1.0, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=22
# [CV]  base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=22, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=22
# [CV]  base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=22, score=0.95, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=23, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=23, score=0.9625, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=23, score=1.0, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=23, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=23, score=0.925, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=24
# [CV]  base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=24, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=24
# [CV]  base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=24, score=0.9625, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=24
# [CV]  base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=24, score=1.0, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=24
# [CV]  base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=24, score=0.925, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=24
# [CV]  base_estimator__max_depth=1, learning_rate=0.7999999999999999, n_estimators=24, score=0.9375, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=20
# [CV]  base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=20, score=0.9375, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=20
# [CV]  base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=20, score=0.9625, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=20
# [CV]  base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=20, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=20
# [CV]  base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=20, score=0.9125, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=20
# [CV]  base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=20, score=0.9125, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=21
# [CV]  base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=21, score=0.9375, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=21
# [CV]  base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=21, score=0.9625, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=21
# [CV]  base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=21, score=1.0, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=21
# [CV]  base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=21, score=0.9125, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=21
# [CV]  base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=21, score=0.9125, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=22
# [CV]  base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=22, score=0.9375, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=22
# [CV]  base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=22, score=0.9625, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=22
# [CV]  base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=22, score=1.0, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=22
# [CV]  base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=22, score=0.9375, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=22
# [CV]  base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=22, score=0.9125, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=23, score=0.9375, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=23, score=0.9625, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=23, score=1.0, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=23, score=0.9375, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=23, score=0.9125, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=24
# [CV]  base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=24, score=0.9375, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=24
# [CV]  base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=24, score=0.9625, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=24
# [CV]  base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=24, score=1.0, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=24
# [CV]  base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=24, score=0.9375, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=24
# [CV]  base_estimator__max_depth=1, learning_rate=0.8999999999999999, n_estimators=24, score=0.9, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=20
# [CV]  base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=20, score=0.9125, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=20
# [CV]  base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=20, score=0.9625, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=20
# [CV]  base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=20, score=1.0, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=20
# [CV]  base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=20, score=0.925, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=20
# [CV]  base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=20, score=0.9125, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=21
# [CV]  base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=21, score=0.9125, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=21
# [CV]  base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=21, score=0.9625, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=21
# [CV]  base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=21, score=1.0, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=21
# [CV]  base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=21, score=0.925, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=21
# [CV]  base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=21, score=0.9125, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=22
# [CV]  base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=22, score=0.9125, total=   0.0s
# [CV] base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=22
# [CV]  base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=22, score=0.9625, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=22
# [CV]  base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=22, score=1.0, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=22
# [CV]  base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=22, score=0.925, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=22
# [CV]  base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=22, score=0.9125, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=23, score=0.9125, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=23, score=0.9625, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=23, score=1.0, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=23, score=0.9125, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=23, score=0.8875, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=24
# [CV]  base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=24, score=0.9125, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=24
# [CV]  base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=24, score=0.9625, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=24
# [CV]  base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=24, score=1.0, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=24
# [CV]  base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=24, score=0.925, total=   0.1s
# [CV] base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=24
# [CV]  base_estimator__max_depth=1, learning_rate=0.9999999999999999, n_estimators=24, score=0.9, total=   0.1s
# [CV] base_estimator__max_depth=2, learning_rate=0.1, n_estimators=20 .
# [CV]  base_estimator__max_depth=2, learning_rate=0.1, n_estimators=20, score=0.9125, total=   0.0s
# [CV] base_estimator__max_depth=2, learning_rate=0.1, n_estimators=20 .
# [CV]  base_estimator__max_depth=2, learning_rate=0.1, n_estimators=20, score=0.975, total=   0.0s
# [CV] base_estimator__max_depth=2, learning_rate=0.1, n_estimators=20 .
# [CV]  base_estimator__max_depth=2, learning_rate=0.1, n_estimators=20, score=1.0, total=   0.1s
# [CV] base_estimator__max_depth=2, learning_rate=0.1, n_estimators=20 .
# [CV]  base_estimator__max_depth=2, learning_rate=0.1, n_estimators=20, score=0.9125, total=   0.1s
# [CV] base_estimator__max_depth=2, learning_rate=0.1, n_estimators=20 .
# [CV]  base_estimator__max_depth=2, learning_rate=0.1, n_estimators=20, score=0.9, total=   0.0s
# [CV] base_estimator__max_depth=2, learning_rate=0.1, n_estimators=21 .
# [CV]  base_estimator__max_depth=2, learning_rate=0.1, n_estimators=21, score=0.9125, total=   0.1s
# [CV] base_estimator__max_depth=2, learning_rate=0.1, n_estimators=21 .
# [CV]  base_estimator__max_depth=2, learning_rate=0.1, n_estimators=21, score=0.975, total=   0.1s
# [CV] base_estimator__max_depth=2, learning_rate=0.1, n_estimators=21 .
# [CV]  base_estimator__max_depth=2, learning_rate=0.1, n_estimators=21, score=1.0, total=   0.1s
# [CV] base_estimator__max_depth=2, learning_rate=0.1, n_estimators=21 .
# [CV]  base_estimator__max_depth=2, learning_rate=0.1, n_estimators=21, score=0.9125, total=   0.1s
# [CV] base_estimator__max_depth=2, learning_rate=0.1, n_estimators=21 .
# [CV]  base_estimator__max_depth=2, learning_rate=0.1, n_estimators=21, score=0.9125, total=   0.1s
# [CV] base_estimator__max_depth=2, learning_rate=0.1, n_estimators=22 .
# [CV]  base_estimator__max_depth=2, learning_rate=0.1, n_estimators=22, score=0.9125, total=   0.1s
# [CV] base_estimator__max_depth=2, learning_rate=0.1, n_estimators=22 .
# ...
# [CV]  base_estimator__max_depth=3, learning_rate=0.7999999999999999, n_estimators=23, score=0.925, total=   0.2s
# [CV] base_estimator__max_depth=3, learning_rate=0.7999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=3, learning_rate=0.7999999999999999, n_estimators=23, score=0.95, total=   0.2s
# [CV] base_estimator__max_depth=3, learning_rate=0.7999999999999999, n_estimators=24
# [CV]  base_estimator__max_depth=3, learning_rate=0.7999999999999999, n_estimators=24, score=0.95, total=   0.2s
# [CV] base_estimator__max_depth=3, learning_rate=0.7999999999999999, n_estimators=24
# [CV]  base_estimator__max_depth=3, learning_rate=0.7999999999999999, n_estimators=24, score=0.9875, total=   0.2s
# [CV] base_estimator__max_depth=3, learning_rate=0.7999999999999999, n_estimators=24
# [CV]  base_estimator__max_depth=3, learning_rate=0.7999999999999999, n_estimators=24, score=0.9625, total=   0.2s
# [CV] base_estimator__max_depth=3, learning_rate=0.7999999999999999, n_estimators=24
# [CV]  base_estimator__max_depth=3, learning_rate=0.7999999999999999, n_estimators=24, score=0.925, total=   0.2s
# [CV] base_estimator__max_depth=3, learning_rate=0.7999999999999999, n_estimators=24
# [CV]  base_estimator__max_depth=3, learning_rate=0.7999999999999999, n_estimators=24, score=0.95, total=   0.2s
# [CV] base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=20
# [CV]  base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=20, score=0.9375, total=   0.1s
# [CV] base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=20
# [CV]  base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=20, score=0.9625, total=   0.1s
# [CV] base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=20
# [CV]  base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=20, score=0.9875, total=   0.2s
# [CV] base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=20
# [CV]  base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=20, score=0.9375, total=   0.2s
# [CV] base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=20
# [CV]  base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=20, score=0.95, total=   0.2s
# [CV] base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=21
# [CV]  base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=21, score=0.9375, total=   0.2s
# [CV] base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=21
# [CV]  base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=21, score=0.9625, total=   0.2s
# [CV] base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=21
# [CV]  base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=21, score=0.975, total=   0.2s
# [CV] base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=21
# [CV]  base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=21, score=0.9375, total=   0.2s
# [CV] base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=21
# [CV]  base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=21, score=0.975, total=   0.2s
# [CV] base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=22
# [CV]  base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=22, score=0.9125, total=   0.2s
# [CV] base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=22
# [CV]  base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=22, score=0.9625, total=   0.2s
# [CV] base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=22
# [CV]  base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=22, score=0.975, total=   0.2s
# [CV] base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=22
# [CV]  base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=22, score=0.9375, total=   0.3s
# [CV] base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=22
# [CV]  base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=22, score=0.975, total=   0.2s
# [CV] base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=23, score=0.9375, total=   0.3s
# [CV] base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=23, score=0.975, total=   0.3s
# [CV] base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=23, score=0.975, total=   0.3s
# [CV] base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=23, score=0.9375, total=   0.3s
# [CV] base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=23, score=0.95, total=   0.2s
# [CV] base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=24
# [CV]  base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=24, score=0.9375, total=   0.3s
# [CV] base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=24
# [CV]  base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=24, score=0.975, total=   0.2s
# [CV] base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=24
# [CV]  base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=24, score=0.975, total=   0.3s
# [CV] base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=24
# [CV]  base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=24, score=0.9375, total=   0.4s
# [CV] base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=24
# [CV]  base_estimator__max_depth=3, learning_rate=0.8999999999999999, n_estimators=24, score=0.9375, total=   0.4s
# [CV] base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=20
# [CV]  base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=20, score=0.95, total=   0.4s
# [CV] base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=20
# [CV]  base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=20, score=0.9875, total=   0.4s
# [CV] base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=20
# [CV]  base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=20, score=0.975, total=   0.4s
# [CV] base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=20
# [CV]  base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=20, score=0.925, total=   0.4s
# [CV] base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=20
# [CV]  base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=20, score=0.9625, total=   0.4s
# [CV] base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=21
# [CV]  base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=21, score=0.95, total=   0.4s
# [CV] base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=21
# [CV]  base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=21, score=0.9875, total=   0.3s
# [CV] base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=21
# [CV]  base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=21, score=0.975, total=   0.4s
# [CV] base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=21
# [CV]  base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=21, score=0.925, total=   0.4s
# [CV] base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=21
# [CV]  base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=21, score=0.95, total=   0.4s
# [CV] base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=22
# [CV]  base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=22, score=0.95, total=   0.4s
# [CV] base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=22
# [CV]  base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=22, score=0.975, total=   0.3s
# [CV] base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=22
# [CV]  base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=22, score=0.975, total=   0.2s
# [CV] base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=22
# [CV]  base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=22, score=0.925, total=   0.3s
# [CV] base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=22
# [CV]  base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=22, score=0.9625, total=   0.3s
# [CV] base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=23, score=0.9375, total=   0.3s
# [CV] base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=23, score=0.9625, total=   0.4s
# [CV] base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=23, score=0.975, total=   0.4s
# [CV] base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=23, score=0.9125, total=   0.4s
# [CV] base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=23
# [CV]  base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=23, score=0.95, total=   0.4s
# [CV] base_estimator__max_depth=3, learning_rate=0.9999999999999999, n_estimators=24
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-b2db3fb0fd52> in <module>
# ----> 1 grid_ada_clf.fit(X_train_std, y_train)
#
# ~/miniconda3/envs/vcdl/lib/python3.6/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     720                 return results_container[0]
#     721
# --> 722             self._run_search(evaluate_candidates)
#     723
#     724         results = results_container[0]
#
# ~/miniconda3/envs/vcdl/lib/python3.6/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1189     def _run_search(self, evaluate_candidates):
#    1190         """Search all candidates in param_grid"""
# -> 1191         evaluate_candidates(ParameterGrid(self.param_grid))
#    1192
#    1193
#
# ~/miniconda3/envs/vcdl/lib/python3.6/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     709                                for parameters, (train, test)
#     710                                in product(candidate_params,
# --> 711                                           cv.split(X, y, groups)))
#     712
#     713                 all_candidate_params.extend(candidate_params)
#
# ~/miniconda3/envs/vcdl/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     918                 self._iterating = self._original_iterator is not None
#     919
# --> 920             while self.dispatch_one_batch(iterator):
#     921                 pass
#     922
#
# ~/miniconda3/envs/vcdl/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~/miniconda3/envs/vcdl/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~/miniconda3/envs/vcdl/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~/miniconda3/envs/vcdl/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~/miniconda3/envs/vcdl/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~/miniconda3/envs/vcdl/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~/miniconda3/envs/vcdl/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     526             estimator.fit(X_train, **fit_params)
#     527         else:
# --> 528             estimator.fit(X_train, y_train, **fit_params)
#     529
#     530     except Exception as e:
#
# ~/miniconda3/envs/vcdl/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py in fit(self, X, y, sample_weight)
#     410
#     411         # Fit
# --> 412         return super(AdaBoostClassifier, self).fit(X, y, sample_weight)
#     413
#     414     def _validate_estimator(self):
#
# ~/miniconda3/envs/vcdl/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py in fit(self, X, y, sample_weight)
#     141                 X, y,
#     142                 sample_weight,
# --> 143                 random_state)
#     144
#     145             # Early termination
#
# ~/miniconda3/envs/vcdl/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py in _boost(self, iboost, X, y, sample_weight, random_state)
#     470         """
#     471         if self.algorithm == 'SAMME.R':
# --> 472             return self._boost_real(iboost, X, y, sample_weight, random_state)
#     473
#     474         else:  # elif self.algorithm == "SAMME":
#
# ~/miniconda3/envs/vcdl/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py in _boost_real(self, iboost, X, y, sample_weight, random_state)
#     496         # Error fraction
#     497         estimator_error = np.mean(
# --> 498             np.average(incorrect, weights=sample_weight, axis=0))
#     499
#     500         # Stop if classification is perfect
#
# ~/miniconda3/envs/vcdl/lib/python3.6/site-packages/numpy/lib/function_base.py in average(a, axis, weights, returned)
#     292
#     293
# --> 294 @array_function_dispatch(_average_dispatcher)
#     295 def average(a, axis=None, weights=None, returned=False):
#     296     """
#
# KeyboardInterrupt:

# %%
grid_ada_clf.best_params_
# Out:
# {'base_estimator__max_depth': 2, 'learning_rate': 0.6, 'n_estimators': 21}

# %%
grid_ada_clf.best_estimator_
# Out:
# AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=2,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=0.6, n_estimators=21, random_state=42)
